# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 저장 시 폰트 깨지지 않도록 세팅

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
# 최신 버전 다운 시 이미지 저장 오류 발생! 5.3.1로 다운해야함
! pip install plotly==5.3.1

# %%
import pandas as pd

data = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet1')
data
# Out:
#    지역명    가족유형  수급가구수     수급가구비
# 0  광진구    모자가족    591  0.799729
# 1  광진구    부자가족    143  0.193505
# 2  광진구    조손가족      3  0.004060
# 3  광진구  청소년한부모      2  0.002706

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet1')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득30이하 광진구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득30이하 광진구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet2')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득30이하 구로구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득30이하 구로구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet3')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득30이하 동작구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득30이하 동작구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet4')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득30이하 마포구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득30이하 마포구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet5')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득30이하 서대문구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득30이하 서대문구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet6')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득30이하 성동구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득30이하 성동구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet7')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득30이하 용산구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득30이하 용산구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet8')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득30이하 종로구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득30이하 종로구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet9')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득30이하 중구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득30이하 중구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet10')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득3040 강남구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득3040 강남구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet11')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득3040 금천구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득3040 금천구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet12')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득3040 성동구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득3040 성동구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet13')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득3040 중구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득3040 중구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet14')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득4050 광진구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득4050 광진구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet15')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득4050 마포구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득4050 마포구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet16')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득4050 성동구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득4050 성동구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet17')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득4050 성북구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득4050 성북구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet18')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득4050 양천구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득4050 양천구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet19')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득4050 종로구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득4050 종로구 유형별 가족비.png',format="png",bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/2023 데청캠/프로젝트/plots')

data1 = pd.read_excel('/content/drive/MyDrive/2023 데청캠/프로젝트/plots.xlsx', sheet_name='Sheet20')
plt.axis('equal')
colors = ['thistle', 'cornsilk', 'lightpink','saddlebrown']
plt.pie(data1['수급가구수'], autopct='%1.1f%%', colors = colors)
plt.title('중위소득4050 중구 유형별 가족비')
plt.legend(labels=['모자가족', '부자가족', '조손가족', '청소년한부모가족'], loc='lower left', bbox_to_anchor=(0.95, 0.3))
plt.savefig('중위소득4050 중구 유형별 가족비.png',format="png",bbox_inches='tight')
